# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop("PassengerId",axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop(0,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.set_index("Pclass",inplace=True)

# %%
df
# Out:
#         Survived                                               Name     Sex  \
# Pclass
# 1              1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3              1                             Heikkinen, Miss. Laina  female
# 1              1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 3              0                           Allen, Mr. William Henry    male
# 3              0                                   Moran, Mr. James    male
# ...          ...                                                ...     ...
# 2              0                              Montvila, Rev. Juozas    male
# 1              1                       Graham, Miss. Margaret Edith  female
# 3              0           Johnston, Miss. Catherine Helen "Carrie"  female
# 1              1                              Behr, Mr. Karl Howell    male
# 3              0                                Dooley, Mr. Patrick    male
#
# ...

# %%
df
# Out:
#         Survived                                               Name     Sex  \
# Pclass
# 1              1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3              1                             Heikkinen, Miss. Laina  female
# 1              1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 3              0                           Allen, Mr. William Henry    male
# 3              0                                   Moran, Mr. James    male
# ...          ...                                                ...     ...
# 2              0                              Montvila, Rev. Juozas    male
# 1              1                       Graham, Miss. Margaret Edith  female
# 3              0           Johnston, Miss. Catherine Helen "Carrie"  female
# 1              1                              Behr, Mr. Karl Howell    male
# 3              0                                Dooley, Mr. Patrick    male
#
# ...

# %%
df.reset_index()
# Out:
#      Pclass  Survived                                               Name  \
# 0         1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 1         3         1                             Heikkinen, Miss. Laina
# 2         1         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 3         3         0                           Allen, Mr. William Henry
# 4         3         0                                   Moran, Mr. James
# ..      ...       ...                                                ...
# 885       2         0                              Montvila, Rev. Juozas
# 886       1         1                       Graham, Miss. Margaret Edith
# 887       3         0           Johnston, Miss. Catherine Helen "Carrie"
# 888       1         1                              Behr, Mr. Karl Howell
# 889       3         0                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#         Survived                                               Name     Sex  \
# Pclass
# 1              1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 1              1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 1              0                            McCarthy, Mr. Timothy J    male
# 3              1                    Sandstrom, Miss. Marguerite Rut  female
# 1              1                           Bonnell, Miss. Elizabeth  female
# ...          ...                                                ...     ...
# 1              1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female
# 1              0                           Carlsson, Mr. Frans Olof    male
# 1              1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female
# 1              1                       Graham, Miss. Margaret Edith  female
# 1              1                              Behr, Mr. Karl Howell    male
#
# ...

# %%
df.dropna(axis=1)
# Out:
#         Survived                                               Name     Sex  \
# Pclass
# 1              1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 1              1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 1              0                            McCarthy, Mr. Timothy J    male
# 3              1                    Sandstrom, Miss. Marguerite Rut  female
# 1              1                           Bonnell, Miss. Elizabeth  female
# ...          ...                                                ...     ...
# 1              1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female
# 1              0                           Carlsson, Mr. Frans Olof    male
# 1              1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female
# 1              1                       Graham, Miss. Margaret Edith  female
# 1              1                              Behr, Mr. Karl Howell    male
#
# ...

# %%
df.reset_index()
# Out:
#      Pclass  Survived                                               Name  \
# 0         1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 1         1         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 2         1         0                            McCarthy, Mr. Timothy J
# 3         3         1                    Sandstrom, Miss. Marguerite Rut
# 4         1         1                           Bonnell, Miss. Elizabeth
# ..      ...       ...                                                ...
# 178       1         1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 179       1         0                           Carlsson, Mr. Frans Olof
# 180       1         1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 181       1         1                       Graham, Miss. Margaret Edith
# 182       1         1                              Behr, Mr. Karl Howell
#
#         Sex   Age  SibSp  Parch    Ticket     Fare        Cabin Embarked
# ...

# %%
g=df.groupby("Survived")

# %%
g.sum()
# Out:
# /tmp/ipykernel_85/1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#               Age  SibSp  Parch        Fare
# Survived
# 0         2481.00     22     27   3842.8957
# 1         4047.42     63     60  10555.9961

# %%
g.mean()
# Out:
# /tmp/ipykernel_85/2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#                 Age     SibSp     Parch       Fare
# Survived
# 0         41.350000  0.366667  0.450000  64.048262
# 1         32.905854  0.512195  0.487805  85.821107

# %%
g.max().T
# Out:
# Survived                          0                         1
# Name      Widener, Mr. Harry Elkins  Young, Miss. Marie Grice
# Sex                            male                      male
# Age                            71.0                      80.0
# SibSp                             3                         3
# Parch                             4                         2
# Ticket                    WE/P 5735                 WE/P 5735
# Fare                          263.0                  512.3292
# Cabin                             T                        G6
# Embarked                          S                         S

# %%
df
# Out:
#         Survived                                               Name     Sex  \
# Pclass
# 1              1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 1              1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 1              0                            McCarthy, Mr. Timothy J    male
# 3              1                    Sandstrom, Miss. Marguerite Rut  female
# 1              1                           Bonnell, Miss. Elizabeth  female
# ...          ...                                                ...     ...
# 1              1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female
# 1              0                           Carlsson, Mr. Frans Olof    male
# 1              1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female
# 1              1                       Graham, Miss. Margaret Edith  female
# 1              1                              Behr, Mr. Karl Howell    male
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#      Pclass  Survived                                               Name  \
# 0         1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 1         1         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 2         1         0                            McCarthy, Mr. Timothy J
# 3         3         1                    Sandstrom, Miss. Marguerite Rut
# 4         1         1                           Bonnell, Miss. Elizabeth
# ..      ...       ...                                                ...
# 178       1         1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 179       1         0                           Carlsson, Mr. Frans Olof
# 180       1         1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 181       1         1                       Graham, Miss. Margaret Edith
# 182       1         1                              Behr, Mr. Karl Howell
#
#         Sex   Age  SibSp  Parch    Ticket     Fare        Cabin Embarked
# ...

# %%
df1=df[['Survived','Name','Age']][0:5]

# %%
df1
# Out:
#    Survived                                               Name   Age
# 0         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 1         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 2         0                            McCarthy, Mr. Timothy J  54.0
# 3         1                    Sandstrom, Miss. Marguerite Rut   4.0
# 4         1                           Bonnell, Miss. Elizabeth  58.0

# %%
df2=df[['Survived','Name','Age']][5:10]

# %%
df2
# Out:
#    Survived                                      Name   Age
# 5         1                     Beesley, Mr. Lawrence  34.0
# 6         1              Sloper, Mr. William Thompson  28.0
# 7         0            Fortune, Mr. Charles Alexander  19.0
# 8         1  Harper, Mrs. Henry Sleeper (Myna Haxtun)  49.0
# 9         0            Ostby, Mr. Engelhart Cornelius  65.0

# %%
pd.concat([df1,df2])
# Out:
#    Survived                                               Name   Age
# 0         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 1         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 2         0                            McCarthy, Mr. Timothy J  54.0
# 3         1                    Sandstrom, Miss. Marguerite Rut   4.0
# 4         1                           Bonnell, Miss. Elizabeth  58.0
# 5         1                              Beesley, Mr. Lawrence  34.0
# 6         1                       Sloper, Mr. William Thompson  28.0
# 7         0                     Fortune, Mr. Charles Alexander  19.0
# 8         1           Harper, Mrs. Henry Sleeper (Myna Haxtun)  49.0
# 9         0                     Ostby, Mr. Engelhart Cornelius  65.0

# %%
df3=pd.concat([df1,df2],axis=1)

# %%
df3.fillna("rocky")
# Out:
#   Survived                                               Name    Age Survived  \
# 0      1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...   38.0    rocky
# 1      1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)   35.0    rocky
# 2      0.0                            McCarthy, Mr. Timothy J   54.0    rocky
# 3      1.0                    Sandstrom, Miss. Marguerite Rut    4.0    rocky
# 4      1.0                           Bonnell, Miss. Elizabeth   58.0    rocky
# 5    rocky                                              rocky  rocky      1.0
# 6    rocky                                              rocky  rocky      1.0
# 7    rocky                                              rocky  rocky      0.0
# 8    rocky                                              rocky  rocky      1.0
# 9    rocky                                              rocky  rocky      0.0
#
#                                        Name    Age
# 0                                     rocky  rocky
# ...

# %%
data={"key1":[1,2,3,4,5],"key2":[6,7,8,9,10],"key3":[1,9,5,6,7]}

# %%
df4=pd.DataFrame(data)

# %%
df4
# Out:
#    key1  key2  key3
# 0     1     6     1
# 1     2     7     9
# 2     3     8     5
# 3     4     9     6
# 4     5    10     7

# %%
data1={"key1":[1,4,5,12,11],"key4":[21,25,6,7,10],"key5":[34,56,1,9,7]}

# %%
df5=pd.DataFrame(data1)

# %%
df5
# Out:
#    key1  key4  key5
# 0     1    21    34
# 1     4    25    56
# 2     5     6     1
# 3    12     7     9
# 4    11    10     7

# %%
pd.merge(df4,df5)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     6     1    21    34
# 1     4     9     6    25    56
# 2     5    10     7     6     1

# %%
pd.merge(df4,df5,how='right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   6.0   1.0    21    34
# 1     4   9.0   6.0    25    56
# 2     5  10.0   7.0     6     1
# 3    12   NaN   NaN     7     9
# 4    11   NaN   NaN    10     7

# %%
pd.merge(df4,df5,how='outer')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   6.0   1.0  21.0  34.0
# 1     2   7.0   9.0   NaN   NaN
# 2     3   8.0   5.0   NaN   NaN
# 3     4   9.0   6.0  25.0  56.0
# 4     5  10.0   7.0   6.0   1.0
# 5    12   NaN   NaN   7.0   9.0
# 6    11   NaN   NaN  10.0   7.0

# %%
pd.merge(df4,df5,how='cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     6     1       1    21    34
# 1        1     6     1       4    25    56
# 2        1     6     1       5     6     1
# 3        1     6     1      12     7     9
# 4        1     6     1      11    10     7
# 5        2     7     9       1    21    34
# 6        2     7     9       4    25    56
# 7        2     7     9       5     6     1
# 8        2     7     9      12     7     9
# 9        2     7     9      11    10     7
# 10       3     8     5       1    21    34
# 11       3     8     5       4    25    56
# 12       3     8     5       5     6     1
# 13       3     8     5      12     7     9
# 14       3     8     5      11    10     7
# 15       4     9     6       1    21    34
# 16       4     9     6       4    25    56
# 17       4     9     6       5     6     1
# 18       4     9     6      12     7     9
# 19       4     9     6      11    10     7
# 20       5    10     7       1    21    34
# ...

# %%
import pandas as pd
data={"key1":[1,2,3,4,5],"key2":[6,7,8,9,10],"key3":[1,9,5,6,7]}
df6=pd.DataFrame(data,index=['!','@','#','$','%'])
df6
# Out:
#    key1  key2  key3
# !     1     6     1
# @     2     7     9
# #     3     8     5
# $     4     9     6
# %     5    10     7

# %%
data1={"key4":[1,4,5,12,11],"key5":[21,25,6,7,10],"key6":[34,56,1,9,7]}
df7=pd.DataFrame(data1,index=['!','@','A','B','%'])
df7
# Out:
#    key4  key5  key6
# !     1    21    34
# @     4    25    56
# A     5     6     1
# B    12     7     9
# %    11    10     7

# %%
df6.join(df7)
# Out:
#    key1  key2  key3  key4  key5  key6
# !     1     6     1   1.0  21.0  34.0
# @     2     7     9   4.0  25.0  56.0
# #     3     8     5   NaN   NaN   NaN
# $     4     9     6   NaN   NaN   NaN
# %     5    10     7  11.0  10.0   7.0

# %%
df6.join(df7,how="left")
# Out:
#    key1  key2  key3  key4  key5  key6
# !     1     6     1   1.0  21.0  34.0
# @     2     7     9   4.0  25.0  56.0
# #     3     8     5   NaN   NaN   NaN
# $     4     9     6   NaN   NaN   NaN
# %     5    10     7  11.0  10.0   7.0

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df["New_age"]=df["Age"].apply(lambda x:x+2)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New_age
# 0      0         A/5 21171   7.2500   NaN        S     24.0
# 1      0          PC 17599  71.2833   C85        C     40.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S     28.0
# 3      0            113803  53.1000  C123        S     37.0
# ...

# %%
def sum_age(x):
    return x+2
df["New_age"]=df["Age"].apply(sum_age)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
